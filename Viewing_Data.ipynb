# %%
import pandas as pd

# %%
organisations = pd.read_csv("/home/rk/raj_data_cb/organizations.csv")
# Out:
# /home/rk/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
jobs=pd.read_csv('/home/rk/raj_data_cb/jobs.csv')

# %%
degrees=pd.read_csv('/home/rk/raj_data_cb/degrees.csv')

# %%
funding_rounds=pd.read_csv('/home/rk/raj_data_cb/funding_rounds.csv')

# %%
funds=pd.read_csv('/home/rk/raj_data_cb/funds.csv')

# %%
investment_partners=pd.read_csv('/home/rk/raj_data_cb/investment_partners.csv')

# %%
investments=pd.read_csv('/home/rk/raj_data_cb/investments.csv')

# %%
investors=pd.read_csv('/home/rk/raj_data_cb/investors.csv')

# %%
org_investments=pd.read_csv('/home/rk/raj_data_cb/org_investments.csv')
# Out:
# /home/rk/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (11,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
people=pd.read_csv('/home/rk/raj_data_cb/people.csv')

# %%
person_investments=pd.read_csv('/home/rk/raj_data_cb/person_investments.csv')

# %%
jobs.head(2)
# Out:
#                             person_uuid                              org_uuid  \
# 0  b42a4f1c-1bed-4390-bce9-0352e5861080  c75dfb95-7099-4597-be14-e31201c65b99
# 1  7b2fd4b2-ca20-40f2-b6f1-73401022a19d  79609a18-e5ba-5be3-63e7-1fbbf6db8334
#
#                                job_uuid  started_on ended_on is_current  \
# 0  b9ff7ca3-d3bd-4ff6-991d-32cd38710e07  2014-11-01      NaN          t
# 1  8dcdc062-1c0d-47b6-9fc9-1b337a62de99         NaN      NaN          t
#
#                                        title   job_type
# 0  Vice President and Senior Project Manager  executive
# 1                      Senior Vice President  executive

# %%
investment_partners.columns
# Out:
# Index(['funding_round_uuid', 'investor_uuid', 'partner_uuid'], dtype='object')

# %%
funding_rounds.head(2)
# Out:
#           company_name country_code state_code      region     city  \
# 0  OnPath Technologies          USA         NJ  NJ - Other  Marlton
# 1       Distributed ID          CAN         ON     Toronto  Toronto
#
#   investment_type announced_on  raised_amount_usd  raised_amount  \
# 0        series_a   2007-03-17          8500000.0            NaN
# 1            seed   2017-02-01           103461.0       135000.0
#
#   raised_amount_currency_code  ...  post_money_valuation  \
# 0                         NaN  ...                   NaN
# 1                         CAD  ...             2135000.0
#
#    post_money_currency_code investor_count  \
# 0                       NaN            NaN
# 1                       CAD            NaN
#
#                                               cb_url  \
# 0  https://www.crunchbase.com/funding-round/onpat...
# 1  https://www.crunchbase.com/funding-round/distr...
#
#                            company_uuid                    funding_round_uuid  \
# 0  dfaccc94-3874-9fa7-f1f9-680dbd7d5f2c  00006645-9ef6-8958-129a-2e225e577eb8
# 1  abb6101f-f808-fa9a-ec1c-1f7b4cc64513  00014924-0e2b-bd9e-65b9-da6cc58959dd
#
#             created_at           updated_at investor_names investor_uuids
# 0  2010-12-14 07:02:56  2018-02-12 23:37:51             {}             {}
# 1  2017-07-08 03:31:12  2018-07-17 07:46:49             {}             {}
#
# [2 rows x 21 columns]

# %%
funds.head(2)
# Out:
#                             entity_uuid                             fund_uuid  \
# 0  f1b977be-3e88-4a7c-aed5-93a502710675  f9a86188-e0f8-42a4-b784-599bd96c134b
# 1  96712e17-5941-6c09-3124-176e08daa746  5509d7da-46cd-46b0-81fc-305c3da84657
#
#                          fund_name announced_on  raised_amount  \
# 0  100K Ventures Accelerator Group          NaN            NaN
# 1                        1517 Fund          NaN            NaN
#
#   raised_amount_currency_code           created_at           updated_at
# 0                         NaN  2018-12-18 20:13:16  2018-12-18 20:13:16
# 1                         NaN  2017-11-14 16:07:57  2018-02-12 22:48:01

# %%
k=organisations.columns.tolist()

# %%
l=''
for itm in k:
    l=l+itm
    l=l+','
l
# Out:
# 'Unnamed: 0,company_name,roles,permalink,domain,homepage_url,country_code,state_code,region,city,address,status,short_description,category_list,category_group_list,funding_rounds,funding_total_usd,founded_on,last_funding_on,closed_on,employee_count,email,phone,facebook_url,linkedin_url,cb_url,logo_url,twitter_url,aliases,uuid,created_at,updated_at,primary_role,type,description,'

# %%
investors.head(2)
# Out:
#   investor_name     roles domain country_code state_code region       city  \
# 0            --  investor    NaN          SGP        NaN    NaN  Singapore
# 1            --  investor    NaN          NaN        NaN    NaN        NaN
#
#      investor_type  investment_count  total_funding_usd  founded_on closed_on  \
# 0  venture_capital               NaN                NaN  2014-01-01       NaN
# 1              NaN               NaN                NaN         NaN       NaN
#
#                                               cb_url  \
# 0  https://www.crunchbase.com/organization/id-cap...
# 1  https://www.crunchbase.com/organization/zernik...
#
#                                             logo_url twitter_url facebook_url  \
# 0  https://crunchbase-production-res.cloudinary.c...         NaN          NaN
# 1  https://crunchbase-production-res.cloudinary.c...         NaN          NaN
#
#                                    uuid           updated_at
# 0  f1a062d3-0aa9-4fb3-a567-26bcb65c10f7  2018-09-30 14:25:14
# 1  fa76148d-89b1-cd6c-8bf9-01129a37c7aa  2018-03-21 15:20:08

# %%
investments.head(2)
# Out:
#                      funding_round_uuid                         investor_uuid  \
# 0  00015b5a-54e6-4285-9c9e-2374cb608dd7  47d6eee4-c487-c86e-2c21-dafcf1125f62
# 1  0001cbd1-f7e2-4a56-607c-c57f46cc7dcb  3213cd7d-06e0-3ecb-3359-29aa8deddfa6
#
#   is_lead_investor
# 0                t
# 1              NaN

# %%
org_investments.head(2)
# Out:
#                           investor_name           roles_x      domain_x  \
# 0  EASME - EU Executive Agency for SMEs  company,investor  ec.europa.eu
# 1  EASME - EU Executive Agency for SMEs  company,investor  ec.europa.eu
#
#   country_code_x state_code_x region_x    city_x      investor_type  \
# 0            BEL          NaN       11  Brussels  government_office
# 1            BEL          NaN       11  Brussels  government_office
#
#    investment_count  total_funding_usd  ...  \
# 0            2602.0                NaN  ...
# 1            2602.0                NaN  ...
#
#                                         linkedin_url  \
# 0  https://www.linkedin.com/company/executive-age...
# 1  https://www.linkedin.com/company/executive-age...
#
#                                         cb_url_y  \
# 0  https://www.crunchbase.com/organization/easme
# 1  https://www.crunchbase.com/organization/easme
#
#                                           logo_url_y  \
# 0  https://crunchbase-production-res.cloudinary.c...
# 1  https://crunchbase-production-res.cloudinary.c...
#
#                   twitter_url_y                          aliases  \
# 0  https://twitter.com/eu_easme  EASME,Executive Agency for SMEs
# 1  https://twitter.com/eu_easme  EASME,Executive Agency for SMEs
#
#           created_at_y           updated_at primary_role          type  \
# 0  2013-03-18 17:36:58  2019-04-01 23:48:57      company  organization
# 1  2013-03-18 17:36:58  2019-04-01 23:48:57      company  organization
#
#                                          description
# 0  The Executive Agency for Small and Medium-size...
# 1  The Executive Agency for Small and Medium-size...
#
# [2 rows x 74 columns]

# %%
person_investments.head(2)
# Out:
#         investor_name     roles domain country_code_x state_code_x region_x  \
# 0  Alfonso Villanueva  investor    NaN            USA           CA       CA
# 1  Alfonso Villanueva  investor    NaN            USA           CA       CA
#
#   city_x investor_type  investment_count  total_funding_usd  ...  \
# 0    NaN         angel              16.0                NaN  ...
# 1    NaN         angel              16.0                NaN  ...
#
#                                           logo_url_y  \
# 0  https://crunchbase-production-res.cloudinary.c...
# 1  https://crunchbase-production-res.cloudinary.c...
#
#                  twitter_url_y facebook_url_y  \
# 0  http://twitter.com/alfvilla            NaN
# 1  http://twitter.com/alfvilla            NaN
#
#                                         linkedin_url  \
# 0  http://www.linkedin.com/pub/alfonso-villanueva...
# 1  http://www.linkedin.com/pub/alfonso-villanueva...
#
#   primary_affiliation_organization  \
# 0                           PayPal
# 1                           PayPal
#
#                     primary_affiliation_title  \
# 0  Global Head Strategy and Office of the CEO
# 1  Global Head Strategy and Office of the CEO
#
#               primary_organization_uuid gender         created_at_y  \
# 0  96ab87ca-00b5-2ebc-f218-86262954e320   male  2013-07-23 21:38:11
# 1  96ab87ca-00b5-2ebc-f218-86262954e320   male  2013-07-23 21:38:11
#
#             updated_at
# 0  2018-08-29 21:31:09
# 1  2018-08-29 21:31:09
#
# [2 rows x 56 columns]

# %%
people.head(2)
# Out:
#   first_name     last_name country_code state_code city  \
# 0      Jenny         Umeda          NaN        NaN  NaN
# 1  WARAPHONG  LEKSAKULCHAI          NaN        NaN  NaN
#
#                                               cb_url  \
# 0      https://www.crunchbase.com/person/jenny-umeda
# 1  https://www.crunchbase.com/person/waraphong-le...
#
#                                             logo_url  \
# 0  https://crunchbase-production-res.cloudinary.c...
# 1  https://crunchbase-production-res.cloudinary.c...
#
#                     twitter_url facebook_url linkedin_url  \
# 0  http://twitter.com/jennyopps          NaN          NaN
# 1                           NaN          NaN          NaN
#
#   primary_affiliation_organization primary_affiliation_title  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
#
#   primary_organization_uuid        gender  \
# 0                       NaN        female
# 1                       NaN  not_provided
#
#                                    uuid           created_at  \
# 0  be11bd38-f9fd-1909-1246-432843bb4c16  2014-01-27 06:04:29
# 1  42b3b0e1-6fc2-070a-ad83-dd78a57c7e5f  2013-10-02 11:36:50
#
#             updated_at
# 0  2018-02-12 23:55:36
# 1  2018-02-13 00:18:31
